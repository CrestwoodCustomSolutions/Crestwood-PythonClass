# %% [markdown]
# <a href="https://colab.research.google.com/github/CrestwoodCustomSolutions/Crestwood-PythonClass/blob/main/Lesson_11_Part_07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Lesson 11.11
import pandas as pd

df1 = pd.DataFrame({"key":["A","B","C","D"],"value1":[1,2,3,4]})
df2 = pd.DataFrame({"key":["A","B","C","D"],"value2":[4,5,6,7]})
df3 = pd.merge(df1,df2,on="key",how="inner")
print(df3)

pd.concat([df1,df2], axis=0)
# Out:
#   key  value1  value2
# 0   A       1       4
# 1   B       2       5
# 2   C       3       6
# 3   D       4       7
#   key  value1  value2
# 0   A     1.0     NaN
# 1   B     2.0     NaN
# 2   C     3.0     NaN
# 3   D     4.0     NaN
# 0   A     NaN     4.0
# 1   B     NaN     5.0
# 2   C     NaN     6.0
# 3   D     NaN     7.0
